# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g= nx.cycle_graph(10)
pos = nx.spring_layout(g)

# %%
nx.draw(g, pos, with_labels=True, node_size=10, node_color='skyblue')
plt.title('networ graph')
plt.show()
