# %%
import matplotlib.pyplot as pyplot

# %%
# !pip install matplotlib seaborn

# %%
labels=('python','scala','c##','java','PHP')
index=(1,2,3,4,5)
size=[45,10,15,30,22]

pyplot.bar(index,size,tick_label=labels)

pyplot.ylabel('usage')
pyplot.xlabel('programing language')

pyplot.show()
